# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./dataset.csv')

# %%
# Out:
# Index(['power_plants_output_geothermal', 'power_plants_output_wind',
#        'power_plants_output_solar', 'power_plants_output_hydro'],
#       dtype='object')

# %%
# węgiel wacha sie miedzy 111 - 118

# %%
resource = df.columns[2:][:5]
plt.figure(figsize=(10, 9))
for res in resource:
    plt.plot(df['date'], df[res], label = res)
plt.plot()
plt.legend()

# %%
resource = df.columns[2:][5:10]
plt.figure(figsize=(10, 9))
for res in resource:
    plt.plot(df['date'], df[res], label = res)
plt.plot()
plt.legend()

# %%
resource = df.columns[2:][5:6]
plt.figure(figsize=(10, 9))
for res in resource:
    plt.plot(df['date'], df[res], label = res)
plt.plot()
plt.legend()

# %%
resource = df.columns[2:][6:7]
plt.figure(figsize=(10, 9))
for res in resource:
    plt.plot(df['date'], df[res], label = res)
plt.plot()
plt.legend()

# %%
renable = df.columns[12:-2]
for r in renable:
    plt.plot(df['date'], df[r], label = r)
plt.plot()
plt.legend()
